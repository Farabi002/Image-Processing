# %%
import cv2
import os

# Load the pre-trained face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Input and output folder
input_folder = r'C:\Users\farab\Desktop\New folder'
output_folder = r'C:\Users\farab\Desktop\out'
os.makedirs(output_folder, exist_ok=True)

# Loop through each image
for img_name in os.listdir(input_folder):
    if not img_name.lower().endswith(('.jpg', '.jpeg', '.png')):
        continue

    img_path = os.path.join(input_folder, img_name)
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    # Blur each detected face
    for (x, y, w, h) in faces:
        face_region = img[y:y+h, x:x+w]
        face_region = cv2.GaussianBlur(face_region, (99, 99), 30)
        img[y:y+h, x:x+w] = face_region

    # Save the result
    output_path = os.path.join(output_folder, img_name)
    cv2.imwrite(output_path, img)

# %%
import cv2
import os

# Load the pre-trained eye detector
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Input and output folders
input_folder = r'C:\Users\farab\Desktop\New folder'
output_folder = r'C:\Users\farab\Desktop\out'
os.makedirs(output_folder, exist_ok=True)

for img_name in os.listdir(input_folder):
    if not img_name.lower().endswith(('.jpg', '.jpeg', '.png')):
        continue

    img_path = os.path.join(input_folder, img_name)
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect eyes
    eyes = eye_cascade.detectMultiScale(gray, scaleFactor=1.03, minNeighbors=8)

    for (x, y, w, h) in eyes:
        # Draw a black rectangle over each eye
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 0, 0), thickness=-1)

    # Save the result
    output_path = os.path.join(output_folder, img_name)
    cv2.imwrite(output_path, img)

# %%
import cv2
import mediapipe as mp
import os

# Initialize MediaPipe Face Detection
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils

# Input and output folders
input_folder = r'C:\Users\farab\Desktop\New folder'
output_folder = r'C:\Users\farab\Desktop\out'
os.makedirs(output_folder, exist_ok=True)

# Setup Face Detection
with mp_face_detection.FaceDetection(model_selection=0, min_detection_confidence=0.5) as face_detection:

    for img_name in os.listdir(input_folder):
        if not img_name.lower().endswith(('.jpg', '.jpeg', '.png')):
            continue

        img_path = os.path.join(input_folder, img_name)
        img = cv2.imread(img_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Detect faces
        results = face_detection.process(img_rgb)

        if results.detections:
            for detection in results.detections:
                bboxC = detection.location_data.relative_bounding_box
                ih, iw, _ = img.shape

                # Get face bounding box
                x1 = int(bboxC.xmin * iw)
                y1 = int(bboxC.ymin * ih)
                w = int(bboxC.width * iw)
                h = int(bboxC.height * ih)

                # Define approximate eye region inside the face
                eye_y_start = y1 + int(h * 0.25)
                eye_y_end = y1 + int(h * 0.45)

                # Draw black rectangle over eye region
                cv2.rectangle(img, (x1, eye_y_start), (x1 + w, eye_y_end), (0, 0, 0), thickness=-1)

        # Save
        output_path = os.path.join(output_folder, img_name)
        cv2.imwrite(output_path, img)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 import cv2
# ----> 2 import mediapipe as mp
#       3 import os
#       5 # Initialize MediaPipe Face Detection
#
# ModuleNotFoundError: No module named 'mediapipe'

# %%
pip install mediapipe
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\farab\AppData\Roaming\Python\Python311\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\farab\AppData\Roaming\Python\Python311\site-packages\~umpy'.
#   You can safely remove it manually.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\farab\\AppData\\Roaming\\Python\\Python311\\site-packages\\cv2\\cv2.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 24.0 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
# ...
